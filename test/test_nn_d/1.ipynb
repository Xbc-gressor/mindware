# %%
import numpy as np
import pandas as pd
import os
import sys
sys.path.append(os.path.abspath('/home/mindware/mindware'))
from mindware import HPO
from mindware.utils.data_manager import DataManager
from sklearn.model_selection import train_test_split
from mindware import CLASSIFICATION,REGRESSION
from mindware.components.models.classification.Autogluon_neural_network import NNClassifier
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 6
#       4 import sys
#       5 sys.path.append(os.path.abspath('/home/mindware/mindware'))
# ----> 6 from mindware import HPO
#       7 from mindware.utils.data_manager import DataManager
#       8 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'HPO' from 'mindware' (unknown location)

# %%
alg = 'Autogluon_neural_network'
#alg = 'neural_network'

# %%
data_dir_1 = 'D:/kaggle_data/automl_data/cls_datasets'

data = pd.read_csv(data_dir_1+'/spambase.csv')
train_data, test_data =train_test_split(data, train_size=0.7,random_state=42)
y_test = test_data.iloc[:,-1].values
#y_test = np.where(y_test == 'P',1,0)

dm = DataManager(encoder='ord')
train_data_node = dm.from_train_df(train_data)
train_data_node = dm.preprocess_fit(train_data_node)
test_data_node = dm.from_test_df(test_data)
test_data_node = dm.preprocess_transform(test_data_node)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <cell line: 10>()
#       8 dm = DataManager()
#       9 train_data_node = dm.from_train_df(train_data)
# ---> 10 train_data_node = dm.preprocess_fit(train_data_node)
#      11 test_data_node = dm.from_test_df(test_data)
#      12 test_data_node = dm.preprocess_transform(test_data_node)
#
# File D:/mindware\mindware\utils\data_manager.py:249, in DataManager.preprocess_fit(self, input_node, task_type, x_encode, label_encode)
#     247 self.x_encoder = None
#     248 self.label_encoder = None
# --> 249 preprocessed_node = self.preprocess(input_node.copy_(), train_phase=True)
#     250 return preprocessed_node
#
# File D:/mindware\mindware\utils\data_manager.py:227, in DataManager.preprocess(self, input_node, task_type, train_phase)
#     225 try:
# ...

# %%
X_val = test_data_node.data[0]
y_val = y_test

# %%
X = train_data_node.data[0]
y = train_data_node.data[1]

cs = {
    'Autogluon_neural_network:activation': 'relu',
  'Autogluon_neural_network:dropout_prob': 0.1,
  'Autogluon_neural_network:embed_exponent': 0.56,
  'Autogluon_neural_network:embedding_size_factor': 1.0,
  'Autogluon_neural_network:epoch_num': 150,
  'Autogluon_neural_network:epochs_wo_improve': 20,
  'Autogluon_neural_network:hidden_size': 128,
  'Autogluon_neural_network:learning_rate': 0.0003,
  'Autogluon_neural_network:max_batch_size': 512,
  'Autogluon_neural_network:max_embedding_dim': 100,
  'Autogluon_neural_network:num_layers': 4,
  'Autogluon_neural_network:optimizer': 'adam',
  'Autogluon_neural_network:use_batchnorm': True,
  'Autogluon_neural_network:weight_decay': 1e-06,
}

# %%
def count_cat_number(data_node):
            ind_number_map = dict()
            for i, t in enumerate(data_node.feature_types):
                if t == 'categorical':
                    ind_number_map[i] = len(np.unique(data_node.data[0][:,i]))+1
            return ind_number_map
        
ind_number_map = count_cat_number(train_data_node)

# %%
new_cs = dict()
for k in cs.keys():
    k_ = k.split(':')[1]
    new_cs[k_] = cs[k]
new_cs
# Out:
# {'activation': 'relu',
#  'dropout_prob': 0.1,
#  'embed_exponent': 0.56,
#  'embedding_size_factor': 1.0,
#  'epoch_num': 150,
#  'epochs_wo_improve': 20,
#  'hidden_size': 128,
#  'learning_rate': 0.0003,
#  'max_batch_size': 512,
#  'max_embedding_dim': 100,
#  'num_layers': 4,
#  'optimizer': 'adam',
#  'use_batchnorm': True,
#  'weight_decay': 1e-06}

# %%
# model = NNClassifier(**new_cs)
# model.get_data_info(ind_number_map)
# model.fit(X, y, X_val, y_val)
# Out:
# Epoch 0: Train loss 4.6376.
# Epoch 0: Val loss 7.8041.
# Epoch 10: Train loss 1.4887.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 3>()
#       1 model = NNClassifier(**new_cs)
#       2 model.get_data_info(ind_number_map)
# ----> 3 model.fit(X, y, X_val, y_val)
#
# File D:/mindware\mindware\components\models\classification\Autogluon_neural_network.py:119, in NNClassifier.fit(self, X, Y, X_val, Y_val)
#     117     continue
#     118 num_train_samples += len(X_train)
# --> 119 y_pred = self.model(X_train)
#     120 loss = l(y_pred, y_train.long().to(self.device))
#     121 optimizer.zero_grad()
#
# File d:\ancaonda\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
# ...

# %%
hpo = HPO(estimator_id=alg, task_type=CLASSIFICATION,metric='auc',
          data_node=train_data_node, time_limit=120, seed=42,
          output_dir='D:/kaggle_data/automl_data/data', ensemble_method='ensemble_selection')
hpo.run()
# Out:
# [2024-12-22 15:27:45,336][Default][INFO][color_logger.py:203] Logfile: d:\mindware\test\test_nn_d\logs\Default_2024-12-22-15-27-45-335729.log
# [2024-12-22 15:27:45,377][Default][INFO][generic_advisor.py:227] [BO auto selection]  acq_optimizer_type: local_random.
# [2024-12-22 15:27:51,902][Default][ERROR][generic_smbo.py:290] Exception in objective function:
# Traceback (most recent call last):
#   File "d:\ancaonda\lib\site-packages\openbox\utils\limit.py", line 14, in wrapper_func
#     ret = obj_func(*obj_args, **obj_kwargs)
#   File "D:/mindware\mindware\modules\base_evaluator.py", line 134, in __call__
#     score = validation(estimator, self.scorer, _x_train, _y_train, _x_val, _y_val,
#   File "D:/mindware\mindware\components\evaluators\evaluate_func.py", line 118, in validation
#     estimator.fit(X_train, y_train, **_fit_params)
#   File "D:/mindware\mindware\components\models\classification\Autogluon_neural_network.py", line 119, in fit
#     y_pred = self.model(X_train)
# ...

# %%
train_data_node.data[0]
# Out:
# array([[5.9e+01, 2.0e-02, 1.6e+00, ..., 0.0e+00, 1.0e+00, 0.0e+00],
#        [4.2e+01, 1.3e+00, 1.7e+00, ..., 0.0e+00, 0.0e+00, 1.0e+00],
#        [5.5e+01, 9.2e+00, 1.8e+00, ..., 0.0e+00, 0.0e+00, 0.0e+00],
#        ...,
#        [7.1e+01, 9.0e-02, 2.5e+00, ..., 0.0e+00, 0.0e+00, 1.0e+00],
#        [2.9e+01, 3.1e-01, 2.0e+00, ..., 0.0e+00, 0.0e+00, 1.0e+00],
#        [3.7e+01, 2.1e-01, 2.0e+00, ..., 0.0e+00, 0.0e+00, 1.0e+00]])

# %%
train_df
# Out:
#        age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 2428  59.0   F            f                  f                         f    f
# 2193  42.0   M            f                  f                         f    f
# 3234  55.0   F            f                  f                         f    f
# 1281  73.0   F            f                  f                         f    t
# 3586  50.0   F            f                  f                         f    f
# ...    ...  ..          ...                ...                       ...  ...
# 2716  60.0   F            f                  f                         f    f
# 453   68.0   M            f                  f                         f    f
# 1189  71.0   F            f                  f                         f    f
# 2165  29.0   F            f                  f                         f    f
# 1623  37.0   F            t                  f                         f    f
#
# ...

# %%
test_df
# Out:
#        age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 2011  54.0   F            f                  f                         f    t
# 491   63.0   F            f                  f                         f    f
# 3119  62.0   F            f                  f                         f    f
# 143   51.0   M            f                  f                         f    f
# 2442  65.0   F            f                  f                         f    t
# ...    ...  ..          ...                ...                       ...  ...
# 1619  43.0   F            f                  f                         f    f
# 1411  64.0   F            f                  f                         f    f
# 1205  32.0   F            f                  f                         f    f
# 1629  67.0   F            f                  f                         f    f
# 2126  37.0   M            f                  f                         f    f
#
# ...
